# %%
import quandl
import matplotlib.pyplot as plt 
import googlemaps
from datetime import datetime
with open('key.txt','r') as f:
    key = f.read()
with open('google.txt','r') as f:
    gkey=f.read()

# %%
trade_terms= quandl.get(["WWDI/ARM_NY_TTF_GNFS_KN","WWDI/LUX_NY_TTF_GNFS_KN"], authtoken=key)
print(trade_terms)
# Out:
#             WWDI/ARM_NY_TTF_GNFS_KN - Value  WWDI/LUX_NY_TTF_GNFS_KN - Value
# Date
# 1960-12-31                              NaN                     4.707956e+08
# 1961-12-31                              NaN                     2.477183e+08
# 1962-12-31                              NaN                     1.188041e+08
# 1963-12-31                              NaN                     5.797145e+07
# 1964-12-31                              NaN                     7.187715e+07
# 1965-12-31                              NaN                     5.633365e+07
# 1966-12-31                              NaN                     2.204477e+07
# 1967-12-31                              NaN                     8.610065e+07
# 1968-12-31                              NaN                     1.832619e+08
# 1969-12-31                              NaN                     4.699609e+08
# 1970-12-31                              NaN                     1.274104e+09
# ...

# %%
trade_terms["WWDI/ARM_NY_TTF_GNFS_KN - Value"].plot()
trade_terms["WWDI/LUX_NY_TTF_GNFS_KN - Value"].plot()
plt.show()

# %%
trade_terms_arm= quandl.get(["WWDI/ARM_NY_TTF_GNFS_KN"], authtoken=key)
print(trade_terms_arm)
# Out:
#             WWDI/ARM_NY_TTF_GNFS_KN - Value
# Date
# 1990-12-31                    -1.190761e+09
# 1991-12-31                    -1.343565e+09
# 1992-12-31                    -1.184962e+09
# 1993-12-31                     8.130899e+10
# 1994-12-31                    -1.049870e+08
# 1995-12-31                    -3.791570e+07
# 1996-12-31                     0.000000e+00
# 1997-12-31                     5.588612e+07
# 1998-12-31                    -7.375673e+07
# 1999-12-31                    -8.873671e+07
# 2000-12-31                    -3.360012e+07
# 2001-12-31                    -7.027472e+07
# 2002-12-31                    -9.543797e+07
# 2003-12-31                    -2.081122e+08
# 2004-12-31                     3.568845e+09
# 2005-12-31                     4.624303e+09
# 2006-12-31                     4.284940e+09
# 2007-12-31                    -1.150554e+10
# 2008-12-31                    -3.488264e+10
# 2009-12-31                    -6.871665e+10
# ...

# %%
trade_terms_arm.describe()
# Out:
#        WWDI/ARM_NY_TTF_GNFS_KN - Value
# count                     2.600000e+01
# mean                     -2.424101e+10
# std                       5.303044e+10
# min                      -1.715867e+11
# 25%                      -3.846755e+10
# 50%                      -1.565496e+08
# 75%                      -3.467902e+07
# max                       8.130899e+10

# %%
x= []
for i in trade_terms_arm["WWDI/ARM_NY_TTF_GNFS_KN - Value"]:
    x.append(i)
del x[3] 
print max(x)
# Out:
# 4624303108.75

# %%
exp_inp=quandl.get(["WWDI/ARM_TM_VAL_MRCH_CD_WT","WWDI/ARM_TX_VAL_MRCH_CD_WT"],authtoken=key)
exp_inp["WWDI/ARM_TM_VAL_MRCH_CD_WT - Value"].plot()
exp_inp["WWDI/ARM_TX_VAL_MRCH_CD_WT - Value"].plot()
plt.show()

# %%
# I could not find a better solution

# %%
stocks=quandl.get(["EOD/BA","EOD/HD","EOD/DD"], authtoken=key)
stocks.drop(['EOD/DD - High'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - High'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - High'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Open'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Open'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Open'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Low'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Low'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Low'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Volume'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Volume'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Volume'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Dividend'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Dividend'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Dividend'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Split'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Split'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Split'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Adj_Open'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Adj_Open'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Adj_Open'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Adj_High'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Adj_High'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Adj_High'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Adj_Low'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Adj_Low'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Adj_Low'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Adj_Volume'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Adj_Volume'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Adj_Volume'], axis = 1, inplace = True)
stocks.drop(['EOD/BA - Adj_Close'], axis = 1, inplace = True)
stocks.drop(['EOD/HD - Adj_Close'], axis = 1, inplace = True)
stocks.drop(['EOD/DD - Adj_Close'], axis = 1, inplace = True)
stocks
# Out:
#             EOD/BA - Close  EOD/HD - Close  EOD/DD - Close
# Date
# 1962-01-02           50.00             NaN          241.50
# 1962-01-03           51.00             NaN          241.75
# 1962-01-04           50.50             NaN          240.00
# 1962-01-05           49.50             NaN          233.50
# 1962-01-08           49.62             NaN          230.00
# 1962-01-09           49.75             NaN          230.75
# 1962-01-10           49.75             NaN          228.12
# 1962-01-11           50.25             NaN          232.00
# 1962-01-12           51.62             NaN          232.00
# 1962-01-15           50.62             NaN          231.50
# 1962-01-16           50.25             NaN          231.50
# 1962-01-17           50.38             NaN          230.25
# 1962-01-18           50.62             NaN          229.25
# 1962-01-19           53.00             NaN          229.50
# 1962-01-22           52.87             NaN          230.00
# ...

# %%
stocks.corr()
# Out:
#                 EOD/BA - Close  EOD/HD - Close  EOD/DD - Close
# EOD/BA - Close        1.000000        0.758047       -0.067087
# EOD/HD - Close        0.758047        1.000000        0.194325
# EOD/DD - Close       -0.067087        0.194325        1.000000

# %%
gmaps = googlemaps.Client(key=gkey)
cities = ["Las Vegas, USA","Chicago, USA","Los Angeles, USA","San Francisco, USA","Salt Lake City, USA", "Mexico City, Mexico",
         "Panama City, Panama",]
now = datetime.now()
for i in cities:
    directions_result = gmaps.directions(i ,"New York, USA", departure_time=now)
    for i in directions_result:
        legs = i["legs"]
        for x in legs:
            dist = x["distance"]
    print dist["text"]
# Out:
# 2,529 mi
# 797 mi
# 2,799 mi
# 2,914 mi
# 2,180 mi
# 4,308 km
# 7,226 km
